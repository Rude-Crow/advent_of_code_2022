# %%
with open("input_day_7.txt") as input_string:
    input_list = list(input_string)
    cleaned_list = []
    for i in input_list: 
        cleaned_list.append(i.removesuffix('\n'))


file_list = []
for i in cleaned_list:
    file_list.append(i.split(' '))

# %%
comp_dir = {}
current_dir = ''
comp_dir['/'] = {}
for i in file_list:
    if i[0] == '$': #command
        if i[1] == 'cd': #change directory
            if i[2] == '..': #go up by one dictionary
                pass
            if i[2] == '/': #go to outer most dictionary
                current_dir = '/'
            else: #go into dictionary in current folder
                pass
        elif i[1] == 'ls': #list directory
            pass
        else:
            pass

    elif i[0] == 'dir': #directory
        pass
    
    else:
        pass
# Out:
#   Cell In[2], line 17
#     if i[2] ==
#                ^
# SyntaxError: invalid syntax

# %%
for i in file_list:
    if i[0] == '$':
        print(i)
    else:
        pass
# Out:
# ['$', 'cd', '/']
# ['$', 'ls']
# ['$', 'cd', 'fchrtcbh']
# ['$', 'ls']
# ['$', 'cd', 'fct']
# ['$', 'ls']
# ['$', 'cd', 'ctzphlhl']
# ['$', 'ls']
# ['$', 'cd', '..']
# ['$', 'cd', '..']
# ['$', 'cd', 'fwttfps']
# ['$', 'ls']
# ['$', 'cd', '..']
# ['$', 'cd', '..']
# ['$', 'cd', 'hlnbrj']
# ['$', 'ls']
# ['$', 'cd', 'mbwgsdcv']
# ['$', 'ls']
# ['$', 'cd', '..']
# ['$', 'cd', '..']
# ['$', 'cd', 'jbt']
# ['$', 'ls']
# ['$', 'cd', 'bbm']
# ['$', 'ls']
# ['$', 'cd', 'nsshzppb']
# ['$', 'ls']
# ['$', 'cd', 'jlcqcb']
# ['$', 'ls']
# ['$', 'cd', 'nzpvt']
# ['$', 'ls']
# ['$', 'cd', 'fct']
# ['$', 'ls']
# ['$', 'cd', 'fct']
# ['$', 'ls']
# ['$', 'cd', '..']
# ['$', 'cd', '..']
# ['$', 'cd', 'lbsng']
# ['$', 'ls']
# ['$', 'cd', 'mzsj']
# ['$', 'ls']
# ['$', 'cd', '..']
# ['$', 'cd', '..']
# ['$', 'cd', 'pfqcbp']
# ['$', 'ls']
# ['$', 'cd', 'fct']
# ['$', 'ls']
# ['$', 'cd', '..']
# ['$', 'cd', 'ssbv']
# ['$', 'ls']
# ['$', 'cd', 'fct']
# ['$', 'ls']
# ['$', 'cd', '..']
# ['$', 'cd', 'pmqj']
# ...
